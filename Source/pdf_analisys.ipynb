# %%
import matplotlib.pyplot as plp
import pandas as pd
from tabulate import tabulate
import tabula

# %%
pdf = tabula.read_pdf('../Data/Elmer Brum 04-03 a 10-03.pdf', pages='all')

# %%
pdf[0]
# Out:
#   Dia do\rinvestimento Quantidade de\rapostas  \
# 0           04/03/2024                      2
# 1           05/03/2024            Sem apostas
# 2           06/03/2024                      1
# 3           07/03/2024            Sem apostas
# 4           08/03/2024                      1
# 5           09/03/2024                      1
# 6           10/03/2024            Sem apostas
# 7                TOTAL                      5
#
#   Valor investido no dia / Resultado\rem R$ sobre o valor investido  \
# 0                              R$ 28,52 / - R$ 28,52
# 1                                                NaN
# 2                              R$ 28,52 / + R$ 14,26
# 3                                                NaN
# 4                               R$ 14,26 / + R$ 9,69
# 5                              R$ 28,52 / - R$ 28,52
# 6                                                NaN
# 7                              R$ 99,82 / - R$ 33,09
#
#   Resultado em %\rsobre a banca
# ...

# %%
pdf[1]
# Out:
#   Esporte                               Campeonato  \
# 0   Tênis  Qualificação\rMaster 1000\rIndian Wells
# 1   Tênis  Qualificação\rMaster 1000\rIndian Wells
#
#                                      Jogo                    Mercado  \
# 0     Maximilian\rMarterer x\rLukas Klein         Vencedor\rMarterer
# 1  Yoshihito\rNishioka x\rJuncheng\rShang  Handicap -1.5\rG Nishioka
#
#          Odd Investimento Resultado
# 0  2.07\r(P)        14,26      0,00
# 1  2.01\r(P)        14,26      0,00

# %%
pdf[4]
# Out:
#    Esporte         Campeonato                Jogo        Mercado         Odd  \
# 0  Futebol  Espanha: La\rLiga  Valência x\rGetafe  Mais de 1.5 G  1.57\r(1X)
#
#   Investimento Resultado
# 0        28,52      0,00

# %%
tabBets = pd.concat(pdf[1:], ignore_index=True)

# %%
tabBets
# Out:
#     Esporte                               Campeonato  \
# 0     Tênis  Qualificação\rMaster 1000\rIndian Wells
# 1     Tênis  Qualificação\rMaster 1000\rIndian Wells
# 2  Basquete                                      NBA
# 3   Futebol                Holanda:\rEerste\rDivisie
# 4   Futebol                        Espanha: La\rLiga
#
#                                         Jogo                     Mercado  \
# 0        Maximilian\rMarterer x\rLukas Klein          Vencedor\rMarterer
# 1     Yoshihito\rNishioka x\rJuncheng\rShang   Handicap -1.5\rG Nishioka
# 2  Philadelphia\r76ers x\rMemphis\rGrizzlies               Mais de 204 P
# 3                      Cambuur x\rGraafschap  Handicap\r+0.5\rGraafschap
# 4                         Valência x\rGetafe               Mais de 1.5 G
#
#           Odd Investimento Resultado
# 0   2.07\r(P)        14,26      0,00
# 1   2.01\r(P)        14,26      0,00
# 2  1.50\r(1X)        28,52     42,78
# 3   1.68\r(P)        14,26     23,95
# ...
